# %%
import pandas as pd

# %%
df = pd.read_csv('employee_insight.csv', index_col=0)

# %% [markdown]
# ### new column - age

# %%
df['clean_birthday'] = pd.to_datetime(df['birthday'])
df.head(1)
# Out:
#             full_name gender              address country  \
# 0  Andreana Nelthropp      M  76864 Holmberg Lane   Japan
#
#                       university                       job_title company  \
# 0  Hiroshima Jogakuin University  Payment Adjustment Coordinator  Dynava
#
#    salary    credit_card  balance     vehicle    birthday shirt_size  \
# 0   93600  visa-electron    88864  Volkswagen  24/06/1996         XS
#
#   clean_birthday
# 0     1996-06-24

# %%
df['year'] = df['clean_birthday'].dt.year

# %%
# our desired column employee's age

from datetime import datetime
today = datetime.today().year
df['age'] = today - df['year']
df.head(2)
# Out:
#             full_name gender                  address country  \
# 0  Andreana Nelthropp      M      76864 Holmberg Lane   Japan
# 1        Janet Angear      M  95564 Autumn Leaf Place   Spain
#
#                         university                       job_title  \
# 0    Hiroshima Jogakuin University  Payment Adjustment Coordinator
# 1  Universidad Abierta Interactiva                 Project Manager
#
#       company  salary    credit_card  balance     vehicle    birthday  \
# 0      Dynava   93600  visa-electron    88864  Volkswagen  24/06/1996
# 1  Brainverse   31546           visa   484569       Mazda  28/05/1999
#
#   shirt_size clean_birthday  year  age
# 0         XS     1996-06-24  1996   26
# 1         XL     1999-05-28  1999   23

# %% [markdown]
# ### new column - continent

# %%
continent = []

for i in df['country']:
    if i == 'Russia':
        continent.append('Asia')
    elif i == 'Japan':
        continent.append('Asia')
    elif i == 'Thailand':
        continent.append('Asia')
    elif i == 'South Korea':
        continent.append('Asia')
    elif i == 'Bangladesh':
        continent.append('Asia')
    elif i == 'Poland':
        continent.append('Europe')
    elif i == 'Croatia':
        continent.append('Europe')
    elif i == 'Norway':
        continent.append('Europe')
    elif i == 'United Kingdom':
        continent.append('Europe')
    elif i == 'Denmark':
        continent.append('Europe')
    elif i == 'Germany':
        continent.append('Europe')
    elif i == 'Switzerland':
        continent.append('Europe')
    elif i == 'Spain':
        continent.append('Europe')
    elif i == 'United States':
        continent.append('North America')
    elif i == 'Canada':
        continent.append('North America')
    elif i == 'Australia':
        continent.append('Oceania')
    else:
        None

# %%
df['continent'] = continent

# %%
df.head(2)
# Out:
#             full_name gender                  address country  \
# 0  Andreana Nelthropp      M      76864 Holmberg Lane   Japan
# 1        Janet Angear      M  95564 Autumn Leaf Place   Spain
#
#                         university                       job_title  \
# 0    Hiroshima Jogakuin University  Payment Adjustment Coordinator
# 1  Universidad Abierta Interactiva                 Project Manager
#
#       company  salary    credit_card  balance     vehicle    birthday  \
# 0      Dynava   93600  visa-electron    88864  Volkswagen  24/06/1996
# 1  Brainverse   31546           visa   484569       Mazda  28/05/1999
#
#   shirt_size clean_birthday  year  age continent
# 0         XS     1996-06-24  1996   26      Asia
# 1         XL     1999-05-28  1999   23    Europe

# %% [markdown]
# ### after paying tax

# %%
# Using this source https://taxsummaries.pwc.com/united-states/individual/taxes-on-personal-income
# Though in my dataset minimum salary are 20030
# I am going to started the operation based on this website

# %%
after_pay_tax = []

for i in df['salary']:
    if i >= 20000 and i <= 41775:
        after_pay_tax.append(i*0.12)
    elif i >=41776 and i <= 89075:
        after_pay_tax.append(i*0.22)
    elif i >= 89076 and i <= 170050:
        after_pay_tax.append(i*0.24)
    else:
        None

# %%
df['income_tax'] = after_pay_tax
df['income_tax'] = df['income_tax'].astype(int)

# %%
df.head()
# Out:
#             full_name gender                  address country  \
# 0  Andreana Nelthropp      M      76864 Holmberg Lane   Japan
# 1        Janet Angear      M  95564 Autumn Leaf Place   Spain
# 2      Julian Desport      F  12802 Pierstorff Circle  Russia
# 3     Jock Olorenshaw      M           20 Kedzie Hill  Russia
# 4  Ethelred McConigal      M      363 Dottie Crossing  Canada
#
#                                       university  \
# 0                  Hiroshima Jogakuin University
# 1                Universidad Abierta Interactiva
# 2  St. Petersburg State Cinema and TV University
# 3       Nevsky Institute of Language and Culture
# 4                            Carleton University
#
#                         job_title     company  salary    credit_card  balance  \
# 0  Payment Adjustment Coordinator      Dynava   93600  visa-electron    88864
# 1                 Project Manager  Brainverse   31546           visa   484569
# 2              Speech Pathologist      Wikido   28385   instapayment   208092
# 3             Executive Secretary     Blogpad   51164     mastercard   248698
# 4      Quality Control Specialist    Blogtags   62046           solo   316809
#
#       vehicle    birthday shirt_size clean_birthday  year  age      continent  \
# 0  Volkswagen  24/06/1996         XS     1996-06-24  1996   26           Asia
# 1       Mazda  28/05/1999         XL     1999-05-28  1999   23         Europe
# 2     Peugeot  03/06/1996        2XL     1996-03-06  1996   26           Asia
# 3      Jaguar  15/02/1994         XL     1994-02-15  1994   28           Asia
# 4         GMC  01/02/1991         XS     1991-01-02  1991   31  North America
#
#    income_tax
# 0       22464
# 1        3785
# 2        3406
# 3       11256
# 4       13650
